# %%
# Importing
import cv2 as cv
import numpy as np

# reading image
img = cv.imread('Encryptedimage.png')
cv.imshow('Encryptedimage', img)

img_0 = img[:, :, 0]
img_1 = img[:, :, 1]
img_2 = img[:, :, 2]

# %%
print(img_0.all() == img_1.all() == img_2.all())
print(img.shape)
# Out:
# True
# (3280, 4896, 3)

# %%
img_0.shape
# Out:
# (3280, 4896)

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
for i in range(0, img_0.shape[0]):
    plt.plot(img_0[i][:])

# %%
sum_vertical = np.sum(img_0, axis = 0)
sum_vertical = sum_vertical/np.max(sum_vertical)
sum_horizontal = np.sum(img_0, axis = 1)
sum_horizontal = sum_horizontal/np.max(sum_horizontal)

# %%
plt.plot(sum_vertical)
plt.plot(sum_horizontal)

# %%
# reading image
from matplotlib.pyplot import figure
figure(figsize=(16, 12))
img = cv.imread('EncryptedImage_center_crop_auto_1024_normalised0to255.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
img_1 = cv.Canny(img, 3, 5)
figure(figsize=(16, 12))
plt.imshow(img_1, cmap='gray')

# %%
img_1 = cv.Canny(img, 100, 200)
figure(figsize=(16, 12))
plt.imshow(img_1, cmap='gray')

# %%
# Resizing image
# for shrinking use cv.INTER_AREA and for expanding image use cv. INTER_LINEAR or cv.INTER_CUBIC
# resized = cv.resize(img, (200, 200), interpolation=cv.INTER_AREA)
# plt.imshow('Mixed breads resiged', resized)

# %%
# img_square = cv.imread('EncryptedImage_center_crop_auto_512.png', cv.IMREAD_GRAYSCALE)
# cv.imshow('Square', img_square)

# %%
# reading image
from matplotlib.pyplot import figure
figure(figsize=(16, 12))
img = cv.imread('testimg_3_auto_normalised_0to255.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
img_1 = cv.Canny(img, 1, 3)
figure(figsize=(16, 12))
plt.imshow(img_1, cmap='gray')
